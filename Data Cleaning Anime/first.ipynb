# %%
import numpy as np 
import pandas as pd

# %%
anime = pd.read_csv('Anime.csv')

# %%
anime.head()
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV         13.0
# 2                       The Founder of Diabolism 3  Web        12.0
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4             Shingeki no Kyojin Season 3: Part II  TV         10.0
#
#               Studio Release_season  \
# 0           ufotable          Fall
# 1  TMS Entertainment         Spring
# 2   B.C MAY PICTURES            NaN
# 3              Bones         Spring
# ...

# %%
anime.shape
# Out:
# (18495, 17)

# %%
anime.iloc[0]['Description']
# Out:
# "'Tanjiro and his friends accompany the Hashira Tengen Uzui to an entertainment district where Tengen’s female ninja agents were gathering information on a demon before they suddenly disappeared. In order to investigate, Tanjiro and the others disguise themselves as women to sneak in!'"

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18495 entries, 0 to 18494
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             18495 non-null  int64
#  1   Name             18495 non-null  object
#  2   Japanese_name    7938 non-null   object
#  3   Type             18495 non-null  object
#  4   Episodes         9501 non-null   float64
#  5   Studio           12018 non-null  object
#  6   Release_season   4116 non-null   object
#  7   Tags             18095 non-null  object
#  8   Rating           15364 non-null  float64
#  9   Release_year     18112 non-null  float64
#  10  End_year         2854 non-null   float64
#  11  Description      18491 non-null  object
#  12  Content_Warning  1840 non-null   object
#  13  Related_Mange    7627 non-null   object
#  14  Related_anime    10063 non-null  object
#  15  Voice_actors     15309 non-null  object
# ...

# %%
#rank
#Name
#Episodes
#Tags
#Rating
#Release_year
#Description
#staff

anime = anime[['Rank', 'Name', 'Episodes', 'Tags', 'Rating', 'Release_year', 'Description', 'staff']]

# %%
anime.iloc[500:505][:]
# Out:
#      Rank                                               Name  Episodes  \
# 500   501                               Stand by Me Doraemon       1.0
# 501   502  Sekai-ichi Hatsukoi: World's Greatest First Lo...       2.0
# 502   503     Magical Girl Lyrical Nanoha: The Movie 2nd A's       1.0
# 503   504  The Garden of Sinners Movie 3: Ever Cry, Never...       1.0
# 504   505                           Gintama: Jump Festa 2015       1.0
#
#                                                   Tags  Rating  Release_year  \
# 500  Comedy, Drama, Sci Fi, Shounen, Cats, Family F...    4.12        2014.0
# 501  BL, Comedy, Romance, Shounen-ai, Romantic Come...    4.12        2011.0
# 502  Fantasy, Magical Girl, Seinen, Contemporary Fa...    4.12        2012.0
# 503  Drama, Mystery, Overpowered Main Characters, S...    4.12        2008.0
# 504  Comedy, Sci Fi, Shounen, Aliens, Gag, Parody, ...    4.12        2015.0
#
#                                            Description  \
# ...

# %%
anime.iloc[12]['staff']
# Out:
# 'Koyoharu Gotouge : Original Creator, Haruo Sotozaki : Director, Ufotable : Series Composition, Gou Shiina : Music, Yuki Kajiura : Music & Song Arrangement & Song Composition & Song Lyrics, Akira Matsushima : Character Design, Masanori Miyake : Producer, Yuuma Takahashi : Producer'

# %%
anime.isnull().sum()
# Out:
# Rank               0
# Name               0
# Episodes        8994
# Tags             400
# Rating          3131
# Release_year     383
# Description        4
# staff           5490
# dtype: int64

# %%
anime.isnull().iloc[0]['Tags']
# Out:
# False

# %%
anime.iloc[0]['Name']
# Out:
# 'Demon Slayer: Kimetsu no Yaiba - Entertainment District Arc'

# %%
anime.fillna({'Rating': 1}, inplace=True)

# %%
anime.dropna(inplace=True)

# %%
anime.shape
# Out:
# (15993, 8)

# %%
anime.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 anime.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
null_data = anime[anime['staff'].isnull()]

# %%
null_data.head(7)
# Out:
#      Rank                                          Name  Episodes  \
# 47     48  Demon Slayer: Kimetsu no Yaiba - Mugen Train       1.0
# 122   123                             The Legend of Hei       1.0
# 162   163                           Hikari: Be My Light       1.0
# 208   209        Yuri!!! on Ice: Welcome to The Madness       1.0
# 234   235                    School Babysitters Special       1.0
# 261   262                       Gintama: The Semi-Final       2.0
# 351   352                              Psychic Princess      16.0
#
#                                                   Tags  Rating  Release_year  \
# 47   Action, Drama, Fantasy, Shounen, Demons, Histo...    4.43        2021.0
# 122  Action, Adventure, Fantasy, Animal Characteris...    4.32        2019.0
# 162  BL, Drama, Shounen-ai, Illness, Psychological,...    4.28        2020.0
# 208                 Sports, Ice Skating, Original Work    4.25        2017.0
# ...

# %%
anime = anime.dropna(subset=['Rating', 'staff'], how ='all')

# %%
anime.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 anime.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
anime = anime[~(anime['Rating'].isnull() & (anime['Rank']>1000))]

# %%
anime= anime.dropna(inplace=True)

# %%
# Out:
# 2
