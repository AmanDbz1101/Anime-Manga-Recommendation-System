# %%
import numpy as np 
import pandas as pd

# %%
manga = pd.read_csv('data.csv')

# %%
manga.to_csv('cleaneddata.csv')

# %%
manga.head()
# Out:
#                                              title  \
# 0               Salad Days (Tang LiuZang) - Part 2
# 1                          The Master of Diabolism
# 2  JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                              A Sign of Affection
# 4                             Moriarty the Patriot
#
#                                          description  rating    year  \
# 0    The second season of Salad Days  Tang LiuZang .     4.7  2021.0
# 1  As the grandmaster who founded the Demonic Sec...     4.7  2017.0
# 2  Set in 1890  Steel Ball Run spotlights Gyro Ze...     4.7  2004.0
# 3  Yuki is a typical college student  whose world...     4.7  2019.0
# 4  Before he was Sherlock’s rival  Moriarty fough...     4.7  2016.0
#
#                                                 tags  \
# 0  BL  Manhua  Romance  Shounen ai  Sports  Webto...
# 1  Action  Adventure  BL  Comedy  Manhua  Mystery...
# 2  Action  Adventure  Horror  Mystery  Seinen  19...
# ...

# %%
manga = manga.drop(manga.columns[3], axis = 1)

# %%
manga['year'][1]
# Out:
# '0        0        0        2021.0\\n1        2017.0\\n2  ...\n1        0        0        2021.0\\n1        2017.0\\n2  ...\n2        0        0        2021.0\\n1        2017.0\\n2  ...\n3        0        0        2021.0\\n1        2017.0\\n2  ...\n4        0        0        2021.0\\n1        2017.0\\n2  ...\n                               ...                        \n70943    0        0        2021.0\\n1        2017.0\\n2  ...\n70944    0        0        2021.0\\n1        2017.0\\n2  ...\n70945    0        0        2021.0\\n1        2017.0\\n2  ...\n70946    0        0        2021.0\\n1        2017.0\\n2  ...\n70947    0        0        2021.0\\n1        2017.0\\n2  ...\nName: year, Length: 70093, dtype: object'

# %%
manga['tags'] = manga['tags'] + manga['new']

# %%
manga.isnull().sum()
# Out:
# title              0
# description       31
# rating         41077
# year             824
# tags               0
# cover              0
# dtype: int64

# %%
manga['year'] = str(manga['year'])

# %%
    for i in range(manga.shape[0]):

        manga['year'][i] = str(manga['year'][i])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16156\3562125382.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manga['year'][i] = str(manga['year'][i])
# C:\Users\User\AppData\Local\Temp\ipykernel_16156\3562125382.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2021.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   manga['year'][i] = str(manga['year'][i])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Python\Projects\Recommendation System\recommender\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# ...

# %%
type(manga.iloc[0]['tags'])
# Out:
# str

# %%
manga.iloc[5]['tags']
# Out:
# 'Comedy  Drama  Ecchi  Harem  Light Novels  Romance  Boarding School  School Life  Adapted to AnimeAt the prestigious Tokyo Metropolitan Advanced Nurturing High School, which aims to produce the country’s future leaders, students are given remarkable freedom. However, they also have to deal with a point system that decides one’s place in the school’s hierarchy! Ayanokoji Kiyotaka has landed at the bottom in the scorned Class D, where he meets Horikita Suzune, who’s determined to work her way back up to Class A, and Kushida Kikyo, who seems like she only wants to make friends. Can they advance through this school where cutthroat competition is the name of the game?Classroom of the Elite (Light Novel)'

# %%
manga['tags'].shape
# Out:
# (70948,)

# %%
manga['new']=manga['new'].map(lambda x: x.replace(':', ' ').replace("-", " "))

# %%
manga['description'][1]
# Out:
# 'As the grandmaster who founded the Demonic Sect, Wei WuXian roamed the world in his wanton ways, hated by millions for the chaos he created. In the end, he was back-stabbed by his dearest shidi and killed by powerful clans that combined to overpower him. He incarnates into the body of a lunatic who was abandoned by his clan and is later, unwillingly, taken away by a famous cultivator among the clans—Lan WangJi, his archenemy.'

# %%
manga['description']=manga['description'].map(lambda x: x.replace(",", " ").replace('-', " ").replace("(", " ").replace(')', " "))

# %%
manga['new'] = manga['rating']

# %%
for i in range (manga['tags'].shape[0]):
    manga[i]['tags'] = manga[i]['tags'].replace("[", ' ').replace(']', '').replace("'", "").replace(",", " ")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Python\Projects\Recommendation System\recommender\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 2
# ...

# %%
manga.shape
# Out:
# (70948, 6)

# %%
manga['description'][0]
# Out:
# 'The second season of\xa0Salad Days (Tang LiuZang).'

# %%
manga.isnull().sum()
# Out:
# title          0
# description    0
# rating         0
# year           0
# tags           0
# cover          0
# new            0
# dtype: int64

# %%
null_data = manga[manga['description'].isnull()]

# %%
manga = manga.dropna(subset=['year'])

# %%
manga.isnull()

# %%
str(manga.iloc[29871]['rating'])
# Out:
# 'nan'

# %%
null_data.head()
# Out:
#                                  title description  rating    year  \
# 14982  The Mountain Bird Cries at Dawn         NaN     3.8  2018.0
# 15830              Monster Hunter Epic         NaN     3.8  2011.0
# 19279                 Otome no Honki!!         NaN     3.6  2012.0
# 20673                 My Monster Lover         NaN     3.6  2019.0
# 20858                Chitose Get You!!         NaN     3.5  2002.0
#
#                                                     tags  \
# 14982                                           BL  Yaoi
# 15830                         Action  Adventure  Fantasy
# 19279             One Shot  Romance  Shoujo  School Life
# 20673                               Josei  Romance  Smut
# 20858  4-koma  Comedy  Seinen  School Life  Slapstick...
#
#                                                    cover  \
# 14982  https://cdn.anime-planet.com/manga/primary/the...
# 15830  https://cdn.anime-planet.com/manga/primary/mon...
# ...

# %%
# Out:
# str

# %%
type(int(manga['new'][1]))
# Out:
# int

# %%
manga.fillna({'rating':0}, inplace=True)

# %%
i=0
for tag in manga['new']:
    if (tag<3.0):
        manga['new'][i] ='lowestranking'
    elif (tag>=3.0 and tag<3.5):
        manga['new'][i] ='lowranking'
    elif (tag>=3.5 and tag<4.0):
        manga['new'][i] ='midranking'
    elif (tag>=4.0 and tag<4.5):
        manga['new'][i] ='highranking'
    elif (tag>=4.5):
        manga['new'][i] ='highestranking'
    elif(tag==0):
        manga['new'][i] ='notrated'    
    
    i+=1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16156\1059975269.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   manga['new'][i] ='highestranking'
# ...
